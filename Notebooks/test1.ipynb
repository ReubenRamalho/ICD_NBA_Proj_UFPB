# %%
import pandas as pd

df_games = pd.read_csv(r"C:\myProject\pythonNotebooks\ICD_NBA_Proj_UFPB\DataSets\games.csv")

df_games
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0        2022-03-12  22101005            Final    1610612748       1610612750
# 1        2022-03-12  22101006            Final    1610612741       1610612739
# 2        2022-03-12  22101007            Final    1610612759       1610612754
# 3        2022-03-12  22101008            Final    1610612744       1610612749
# 4        2022-03-12  22101009            Final    1610612743       1610612761
# ...             ...       ...              ...           ...              ...
# 25791    2014-10-06  11400007            Final    1610612737       1610612740
# 25792    2014-10-06  11400004            Final    1610612741       1610612764
# 25793    2014-10-06  11400005            Final    1610612747       1610612743
# 25794    2014-10-05  11400002            Final    1610612761       1610612758
# 25795    2014-10-04  11400001            Final    1610612748       1610612740
#
# ...

# %%
df_games.loc[df_games["SEASON"] == 2021]
# Out:
#      GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0       2022-03-12  22101005            Final    1610612748       1610612750
# 1       2022-03-12  22101006            Final    1610612741       1610612739
# 2       2022-03-12  22101007            Final    1610612759       1610612754
# 3       2022-03-12  22101008            Final    1610612744       1610612749
# 4       2022-03-12  22101009            Final    1610612743       1610612761
# ...            ...       ...              ...           ...              ...
# 1071    2021-10-04  12100007            Final    1610612759       1610612762
# 1072    2021-10-04  12100008            Final    1610612757       1610612744
# 1073    2021-10-04  12100009            Final    1610612758       1610612756
# 1074    2021-10-04  12100010            Final    1610612746       1610612743
# 1075    2021-10-03  12100001            Final    1610612747       1610612751
#
# ...

# %%
df_teams = pd.read_csv(r"C:\myProject\pythonNotebooks\ICD_NBA_Proj_UFPB\DataSets\teams.csv",index_col= False ,usecols= [1, 5])

df_teams
# Out:
#        TEAM_ID       NICKNAME
# 0   1610612737          Hawks
# 1   1610612738        Celtics
# 2   1610612740       Pelicans
# 3   1610612741          Bulls
# 4   1610612742      Mavericks
# 5   1610612743        Nuggets
# 6   1610612745        Rockets
# 7   1610612746       Clippers
# 8   1610612747         Lakers
# 9   1610612748           Heat
# 10  1610612749          Bucks
# 11  1610612750   Timberwolves
# 12  1610612751           Nets
# 13  1610612752         Knicks
# 14  1610612753          Magic
# 15  1610612754         Pacers
# 16  1610612755          76ers
# 17  1610612756           Suns
# 18  1610612757  Trail Blazers
# 19  1610612758          Kings
# 20  1610612759          Spurs
# 21  1610612760        Thunder
# 22  1610612761        Raptors
# 23  1610612762           Jazz
# 24  1610612763      Grizzlies
# 25  1610612764        Wizards
# 26  1610612765        Pistons
# 27  1610612766        Hornets
# 28  1610612739      Cavaliers
# 29  1610612744       Warriors

# %%
df_teams.set_index('TEAM_ID').to_dict()['NICKNAME']
# Out:
# {1610612737: 'Hawks',
#  1610612738: 'Celtics',
#  1610612740: 'Pelicans',
#  1610612741: 'Bulls',
#  1610612742: 'Mavericks',
#  1610612743: 'Nuggets',
#  1610612745: 'Rockets',
#  1610612746: 'Clippers',
#  1610612747: 'Lakers',
#  1610612748: 'Heat',
#  1610612749: 'Bucks',
#  1610612750: 'Timberwolves',
#  1610612751: 'Nets',
#  1610612752: 'Knicks',
#  1610612753: 'Magic',
#  1610612754: 'Pacers',
#  1610612755: '76ers',
#  1610612756: 'Suns',
#  1610612757: 'Trail Blazers',
#  1610612758: 'Kings',
#  1610612759: 'Spurs',
#  1610612760: 'Thunder',
#  1610612761: 'Raptors',
#  1610612762: 'Jazz',
#  1610612763: 'Grizzlies',
#  1610612764: 'Wizards',
#  1610612765: 'Pistons',
#  1610612766: 'Hornets',
#  1610612739: 'Cavaliers',
#  1610612744: 'Warriors'}
